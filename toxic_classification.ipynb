# %% [markdown]
# <h2 align=center> Toxic Comments Classification using 1D CNN with Keras</h2>

# %% [markdown]
# ### Task 1: Import Packages and Functions

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.preprocessing import text, sequence
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation
from tensorflow.keras.layers import Embedding
from tensorflow.keras.layers import Conv1D, GlobalMaxPooling1D, MaxPooling1D
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import EarlyStopping
print(tf.__version__)
# Out:
# 2.12.0

# %% [markdown]
# ### Task 2: Load and Explore Data

# %%
# Load data
train=pd.read_csv('/train.csv')
test=pd.read_csv('/test.csv')
train.head()
# Out:
#                                         comment_text  toxic
# 0  Explanation\nWhy the edits made under my usern...      0
# 1  D'aww! He matches this background colour I'm s...      0
# 2  Hey man, I'm really not trying to edit war. It...      0
# 3  "\nMore\nI can't make any real suggestions on ...      0
# 4  You, sir, are my hero. Any chance you remember...      0

# %%
x= train['comment_text'].values

# %% [markdown]
# ### Task 3- View few toxic comments

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
comments = train['comment_text'].loc[train['toxic']==1].values
wordcloud = WordCloud(
    width = 640,
    height = 640,
    background_color = 'black',
    stopwords = STOPWORDS).generate(str(comments))
fig = plt.figure(
    figsize = (12, 8),
    facecolor = 'k',
    edgecolor = 'k')
plt.imshow(wordcloud, interpolation = 'bilinear')
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()

# %%
y=train['toxic'].values

# %%
# Plot frequency of toxic comments
train['toxic'].plot(kind='hist', title='Distribution of toxic comments')
# Out:
# <Axes: title={'center': 'Distribution of toxic comments'}, ylabel='Frequency'>

# %% [markdown]
# ### Task 4: Data Prep — Tokenize and Pad Text Data

# %%
max_features=20000
max_text_len=400
embedding_dim = 100
trunc_type='post'
padding_type='post'
oov_tok = "<OOV>"
filters=128
kernel_size=5
hidden_dims=24

# %%
tokenizer=text.Tokenizer(max_features, oov_token=oov_tok)
tokenizer.fit_on_texts(list(x))
word_index = tokenizer.word_index
tokenized=tokenizer.texts_to_sequences(x)
X_train=sequence.pad_sequences(tokenized,maxlen=max_text_len, padding=padding_type, truncating=trunc_type)

# %% [markdown]
# ### Task 5: Create the Embedding Layer

# %%
model=Sequential()
model.add(Embedding(max_features,embedding_dim,input_length=max_text_len))
model.add(Dropout(0.2))
model.add(Conv1D(filters,kernel_size,padding='valid',activation='relu'))
model.add(MaxPooling1D())
model.add(Conv1D(filters,5,padding='valid',activation='relu'))
model.add(GlobalMaxPooling1D())
model.add(Dense(hidden_dims,activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(1,activation='sigmoid'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 400, 100)          2000000
#
#  dropout (Dropout)           (None, 400, 100)          0
#
#  conv1d (Conv1D)             (None, 396, 128)          64128
#
#  max_pooling1d (MaxPooling1D  (None, 198, 128)         0
#  )
#
#  conv1d_1 (Conv1D)           (None, 194, 128)          82048
#
#  global_max_pooling1d (Globa  (None, 128)              0
#  lMaxPooling1D)
#
#  dense (Dense)               (None, 24)                3096
#
#  dropout_1 (Dropout)         (None, 24)                0
#
#  dense_1 (Dense)             (None, 1)                 25
#
# =================================================================
# Total params: 2,149,297
# Trainable params: 2,149,297
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

# %% [markdown]
# ### Task 7: Train Model

# %%
X_train,X_val,y_train,y_val=train_test_split(X_train,y,test_size=0.15,random_state=1)

# %%
batch_size=64
early=EarlyStopping(monitor='val_accuracy',patience=3,mode='max')
hist=model.fit(X_train,y_train,batch_size=batch_size,epochs=20,validation_data=(X_val,y_val),callbacks=[early])
# Out:
# Epoch 1/20
# 2120/2120 [==============================] - 162s 71ms/step - loss: 0.1446 - accuracy: 0.9472 - val_loss: 0.1046 - val_accuracy: 0.9608
# Epoch 2/20
# 2120/2120 [==============================] - 42s 20ms/step - loss: 0.0921 - accuracy: 0.9634 - val_loss: 0.1112 - val_accuracy: 0.9626
# Epoch 3/20
# 2120/2120 [==============================] - 36s 17ms/step - loss: 0.0693 - accuracy: 0.9738 - val_loss: 0.1207 - val_accuracy: 0.9585
# Epoch 4/20
# 2120/2120 [==============================] - 32s 15ms/step - loss: 0.0479 - accuracy: 0.9824 - val_loss: 0.1659 - val_accuracy: 0.9589
# Epoch 5/20
# 2120/2120 [==============================] - 30s 14ms/step - loss: 0.0312 - accuracy: 0.9892 - val_loss: 0.1676 - val_accuracy: 0.9573

# %%
model.save('toxic_classification.h5')

# %% [markdown]
# ### Task-8 Plot accuracy vs epoch and loss vs epoch

# %%
epochs = range(len(hist.history['accuracy']))
plt.plot(epochs,hist.history['accuracy'],label='Validation')
plt.plot(epochs,hist.history['val_accuracy'],label='Training')
plt.xlabel("Epochs")
plt.ylabel('Accuracy')
plt.xticks(range(len(hist.history['accuracy'])),labels=[1,2,3,4,5])
plt.title('Accuracy vs Epoch')
plt.legend()
plt.show()

# %%
epochs = range(len(hist.history['accuracy']))
plt.plot(epochs,hist.history['loss'],label='Validation')
plt.plot(epochs,hist.history['val_loss'],label='Training')
plt.xlabel("Epochs")
plt.ylabel('Loss')
plt.xticks(range(len(hist.history['accuracy'])),labels=[1,2,3,4,5])
plt.title('Loss vs Epoch')
plt.legend()
plt.show()

# %% [markdown]
# ### Task 9: Evaluate Model

# %%
model.evaluate(X_val,y_val)
# Out:
# 748/748 [==============================] - 3s 3ms/step - loss: 0.1676 - accuracy: 0.9573
# [0.16760136187076569, 0.9573028087615967]

# %% [markdown]
# ### Task 10- Make predictions

# %%
x_test=test['comment_text'].values

# %%
tokenized=tokenizer.texts_to_sequences(x_test)
X_test=sequence.pad_sequences(tokenized,maxlen=max_text_len, padding=padding_type, truncating=trunc_type)

# %%
y_test=model.predict(X_test,verbose=1,batch_size=128)
# Out:
# 1197/1197 [==============================] - 6s 5ms/step

# %%
test['toxic']=['not toxic' if x < .5 else 'toxic' for x in y_test]
test.head(20)
# Out:
#                                          comment_text      toxic
# 0   Yo bitch Ja Rule is more succesful then you'll...      toxic
# 1   == From RfC == \n\n The title is fine as it is...  not toxic
# 2   " \n\n == Sources == \n\n * Zawe Ashton on Lap...  not toxic
# 3   :If you have a look back at the source, the in...  not toxic
# 4           I don't anonymously edit articles at all.  not toxic
# 5   Thank you for understanding. I think very high...  not toxic
# 6   Please do not add nonsense to Wikipedia. Such ...  not toxic
# 7                    :Dear god this site is horrible.      toxic
# 8   " \n Only a fool can believe in such numbers. ...  not toxic
# 9   == Double Redirects == \n\n When fixing double...  not toxic
# 10  I think its crap that the link to roggenbier i...      toxic
# 11  "::: Somebody will invariably try to add Relig...  not toxic
# 12  , 25 February 2010 (UTC) \n\n :::Looking it ov...  not toxic
# 13  " \n\n It says it right there that it IS a typ...  not toxic
# 14  " \n\n == Before adding a new product to the l...  not toxic
# 15  ==Current Position== \n Anyone have confirmati...  not toxic
# 16                           this other one from 1897  not toxic
# 17  == Reason for banning throwing == \n\n This ar...  not toxic
# 18  :: Wallamoose was changing the cited material ...  not toxic
# 19             |blocked]] from editing Wikipedia.   |  not toxic

# %% [markdown]
# ### Display toxic as well as non-toxic comments

# %%
list(test.loc[7])
# Out:
# [':Dear god this site is horrible.', 'toxic']

# %%
list(test.loc[5])
# Out:
# ['Thank you for understanding. I think very highly of you and would not revert without discussion.',
#  'not toxic']

# %%
import pickle

# %%
filename = 'toxicity'

# %%
# pickle.dump(model, open(filename, 'wb'))

# %%
with open('model.pkl', 'wb') as filename:
    pickle.dump(model, filename)

# %%
with open('model.pkl', 'rb') as filename:
    loaded_model = pickle.load(filename)

# make predictions using the loaded model
loaded_model.predict(X_val)
# Out:
# 748/748 [==============================] - 2s 2ms/step
# array([[9.6502453e-01],
#        [1.8760780e-05],
#        [1.0814436e-01],
#        ...,
#        [2.5813730e-04],
#        [1.0532436e-04],
#        [2.4066343e-05]], dtype=float32)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
file_path = '/content/drive/My Drive/Colab Notebooks/model.pkl'
with open(file_path, 'wb') as f:
    f.write(open('model.pkl', 'rb').read())
